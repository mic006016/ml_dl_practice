# %%
print("welcome");
# Out:
# welcome

# %%
print('화요일이닷');
# Out:
# 화요일이닷

# %%
# 아래 셀을 만들고, 실행하는 결과도 보여줘
# shift + enter

# %%
food = input("먹고 싶은 음식은");
food # 변수명만 쓰면 input(food)
# Out:
# 먹고 싶은 음식은 치킨
# '치킨'
