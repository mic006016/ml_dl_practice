# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

# %%
html = '<h1 id="title">출판네트워크</h1><div class="top"><ul class="menu"><li><a href=http://www.hanbit.co.kr/member/login.html class="login">로그인</a></li></ul><ul class="brand"><li><a href="http://www.hanbit.co.kr/media/">미디어</a></li><li><a href="http://www.hanbit.co.kr/academy/">아카데미</a></li></ul></div>'

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <h1 id="title">
#  출판네트워크
# </h1>
# <div class="top">
#  <ul class="menu">
#   <li>
#    <a class="login" href="http://www.hanbit.co.kr/member/login.html">
#     로그인
#    </a>
#   </li>
#  </ul>
#  <ul class="brand">
#   <li>
#    <a href="http://www.hanbit.co.kr/media/">
#     미디어
#    </a>
#   </li>
#   <li>
#    <a href="http://www.hanbit.co.kr/academy/">
#     아카데미
#    </a>
#   </li>
#  </ul>
# </div>

# %%
soup.h1 # 태그 추출
# Out:
# <h1 id="title">출판네트워크</h1>

# %%
soup.h1.text # 태그 사이의 텍스트를 추출
# Out:
# '출판네트워크'

# %%
h1_tag = soup.h1
h1_tag
# Out:
# <h1 id="title">출판네트워크</h1>

# %%
h1_text = h1_tag.text
h1_text
# Out:
# '출판네트워크'

# %%
div_tag = soup.div
div_tag
# Out:
# <div class="top"><ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li></ul><ul class="brand"><li><a href="http://www.hanbit.co.kr/media/">미디어</a></li><li><a href="http://www.hanbit.co.kr/academy/">아카데미</a></li></ul></div>

# %%
div_text = div_tag.text
div_text
# Out:
# '로그인미디어아카데미'

# %%
ul_tag = soup.ul
ul_tag
# Out:
# <ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li></ul>

# %%
ul_text = ul_tag.text
ul_text
# Out:
# '로그인'

# %%
li_tag = soup.li
li_tag
# Out:
# <li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li>

# %%
a_tag = soup.a
a_tag
# Out:
# <a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a>

# %%
ul_tag_all = soup.find_all('ul')
ul_tag_all
# Out:
# [<ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li></ul>,
#  <ul class="brand"><li><a href="http://www.hanbit.co.kr/media/">미디어</a></li><li><a href="http://www.hanbit.co.kr/academy/">아카데미</a></li></ul>]

# %%
type(ul_tag_all[0])
# Out:
# bs4.element.Tag

# %%
tag1 = ul_tag_all[0]
tag1
# Out:
# <ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li></ul>

# %%
tag2 = ul_tag_all[1]
tag2
# Out:
# <ul class="brand"><li><a href="http://www.hanbit.co.kr/media/">미디어</a></li><li><a href="http://www.hanbit.co.kr/academy/">아카데미</a></li></ul>

# %%
# 리스트 --> for문, map()
for x in ul_tag_all:
    print(x)
# Out:
# <ul class="menu"><li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li></ul>
# <ul class="brand"><li><a href="http://www.hanbit.co.kr/media/">미디어</a></li><li><a href="http://www.hanbit.co.kr/academy/">아카데미</a></li></ul>

# %%
li_tag_all = soup.find_all('li')
li_tag_all
# Out:
# [<li><a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a></li>,
#  <li><a href="http://www.hanbit.co.kr/media/">미디어</a></li>,
#  <li><a href="http://www.hanbit.co.kr/academy/">아카데미</a></li>]

# %%
a_tag_all = soup.find_all('a')
a_tag_all
# Out:
# [<a class="login" href="http://www.hanbit.co.kr/member/login.html">로그인</a>,
#  <a href="http://www.hanbit.co.kr/media/">미디어</a>,
#  <a href="http://www.hanbit.co.kr/academy/">아카데미</a>]

# %%
a_tag.attrs
# Out:
# {'href': 'http://www.hanbit.co.kr/member/login.html', 'class': ['login']}

# %%
a_tag['href']
# Out:
# 'http://www.hanbit.co.kr/member/login.html'

# %%
a_tag['class']
# Out:
# ['login']

# %%
ul_tag_2 = soup.find('ul', attrs = {'class':'brand'})
ul_tag_2
# Out:
# <ul class="brand"><li><a href="http://www.hanbit.co.kr/media/">미디어</a></li><li><a href="http://www.hanbit.co.kr/academy/">아카데미</a></li></ul>

# %%
title = soup.find(id='title')
title
# Out:
# <h1 id="title">출판네트워크</h1>

# %%
title.string
# Out:
# '출판네트워크'

# %%
li_list = soup.select('div>ul.brand>li')
li_list
# Out:
# [<li><a href="http://www.hanbit.co.kr/media/">미디어</a></li>,
#  <li><a href="http://www.hanbit.co.kr/academy/">아카데미</a></li>]

# %%
for li in li_list:
    print(li.string)
# Out:
# 미디어
# 아카데미
